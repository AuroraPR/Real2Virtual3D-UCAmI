# %%
import cv2
import time

import numpy as np
import os
import glob

path ="./out/"
path_fuzzy =path+"cam2/"



#files = glob.glob(path_fuzzy+"*")
#for f in files:
#    os.remove(f)

#files = glob.glob(path_raw+"*")
#for f in files:
#    os.remove(f)

files = glob.glob(path_fuzzy+"*")
for f in files:
    os.remove(f)    


print("GO")
capture = cv2.VideoCapture("rtsp://Adetem:AuroraJavi@192.168.1.102:554/stream2")
print("DONE,",capture.isOpened())

#count=0
#count=0
lastts = int(time.time())
    
while (capture.isOpened()):
    
    ret, frame = capture.read()
    
    write=False
    ts=int(time.time())
    if(ts != lastts):
        lastts=ts
        print("Time new :",lastts)
        write=True
        
   
#    cv2.imwrite(path_fuzzy+str(ts)+".jpg", frame, [int(cv2.IMWRITE_JPEG_QUALITY), 10])
    if(write):
        print('Restaured Dimensions : ',frame.shape)
        cv2.imwrite(path_fuzzy+str(int(ts))+".png", frame, [int(cv2.IMWRITE_PNG_COMPRESSION), 9])
    

    cv2.imshow('webCam',frame)
    
    keyCode = cv2.waitKey(1)
    if (keyCode == ord('s')):
            break


    if cv2.getWindowProperty('webCam', cv2.WND_PROP_VISIBLE) <1:
        break
        
    #count=count+1
    #if(count > 100):
    #    break
        
    #time.sleep(3)        

capture.release()
cv2.destroyAllWindows()
# Out:
# GO
# DONE, True
# Time new : 1689846706
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846707
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846708
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846709
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846710
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846711
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846712
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846713
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846714
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846715
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846716
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846717
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846718
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846719
# Restaured Dimensions :  (360, 640, 3)
# Time new : 1689846720
# Restaured Dimensions :  (360, 640, 3)
# ...
